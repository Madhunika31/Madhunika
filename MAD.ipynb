# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\My Uber Drives - 2016.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(y="START*",order= pd.value_counts(df['START*']).iloc[:10].index, data=df)
plt.show()

# %%
df['STOP*'].value_counts().head(10)
# Out:
# Cary                203
# Unknown Location    149
# Morrisville          84
# Whitebridge          65
# Islamabad            58
# Durham               36
# Lahore               36
# Raleigh              29
# Kar?chi              26
# Apex                 17
# Name: STOP*, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(y="STOP*",order= pd.value_counts(df['STOP*']).iloc[:10].index, data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
df['CATEGORY*'].unique()
# Out:
# array(['Business', 'Personal', nan], dtype=object)

# %%
category = pd.crosstab(index = df['CATEGORY*'], columns ='count of records')

category
# Out:
# col_0      count of records
# CATEGORY*
# Business               1078
# Personal                 77

# %%
category.plot(kind='bar', color='r')
# Out:
# <Axes: xlabel='CATEGORY*'>
